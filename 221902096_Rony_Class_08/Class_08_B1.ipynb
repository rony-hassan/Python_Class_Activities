# %%
#Example 01:
dictionary = dict()

dictionary['abc'] = 34
dictionary['xyz'] = {1:23, 2:56}
dictionary[3] = [2,4,5]

print(dictionary)
dictionary['xyz'][2]
print(dictionary[3][2])

for key, value in dictionary.items():
  print(key, value)
# Out:
# {'abc': 34, 'xyz': {1: 23, 2: 56}, 3: [2, 4, 5]}
# 5
# abc 34
# xyz {1: 23, 2: 56}
# 3 [2, 4, 5]

# %%
from os import name
#Example 02:

dict_ = dict()

dict_ = {
    'name' : 'Alice',
    'age' : 25,
    'city' : 'New York'
}
dict_['job'] = 'engineer'

print(dict_['name'])

dict_['city'] = 'San Fransisco'
print(dict_['city'])

if 'age' in dict_:
  print("age exist in dict_")
else:
  print("age does not exists.")
# Out:
# Alice
# San Fransisco
# age exist in dict_

# %%
#Example 03:
from random import randint
import time
listlen = 1000000
list_of_numbers = listlen * [0]
dict_of_numbers = dict()

for i in range(listlen):
  n = randint(1000000, 9999999)
  list_of_numbers[i] = n
  dict_of_numbers[n] = 1

start_time = time.time()
8675309 in list_of_numbers
end_time = time.time()
print(f'In case of list: {end_time - start_time}')

start_time = time.time()
8675309 in dict_of_numbers
end_time = time.time()
print(f'In case of dictionary: {end_time - start_time}')
# Out:
# In case of list: 0.014819860458374023
# In case of dictionary: 6.914138793945312e-05

# %%
#Example 04:
result = dict()

result = {
    'Rony': 3.67,
    'Tasnim': 3.62,
    'Mustakim': 3.60,
    'Shitol': 3.50,
    'Nur': 3.40
}

for key, value in result.items():
  print(f'{key} : {value}')
# Out:
# Rony : 3.67
# Tasnim : 3.62
# Mustakim : 3.6
# Shitol : 3.5
# Nur : 3.4

# %%
#Example 05:
product = dict()

product = {
    'Clock': 250,
    'Watch' : 350,
    'Laptop' : 50000,
    'Phone': 20000,
    'Tablet' : 30000
}

sum = 0
for value in product.values():
  sum += value
print(f'Total price of the product: {sum}')
# Out:
# Total price of the product: 100600

# %%
#Example 06:
words = '''Lately, I’ve been noticing how my sentences have a tendency to keep going when I write them onscreen. This goes for concentrated writing as well as correspondence. (Twain probably believed that correspondence, in an ideal world, also demands concentration. But he never used email.) Last week I caught myself packing four conjunctions into a three-line sentence in an email. That’s inexcusable. Since then, I have tried to eschew conjunctions whenever possible. Gone are the commas, the and’s, but’s, and so’s; in are staccato declaratives. Better to read like bad Hemingway than bad Faulkner.

Length–as we all know, and for lack of a more original or effective way of saying it–matters. But (ahem), it’s also a matter of how you use it. Style and length are technically two different things.

Try putting some prose onscreen, though, and they mix themselves up pretty quickly. This has much to do with the time constraints we claim to feel in the digital age. We don’t have time to compose letters and post them anymore–much less pay postage, what with all the banks kinda-sorta losing our money these days–so we blast a few emails. We don’t have time to talk, so we text. We don’t have time to text to specific people, so we update our Facebook status. We don’t have time to write essays, so we blog.

I’m less interested by the superficial reduction of words–i.e. the always charming imho or c u l8r–than the genres in which those communications occur: blogs, texts, tweets, emails. All these interstitial communiques, do they really reflect super brevity that would make Twain proud? Or do they just reflect poorly stylized writing that desperately seeks a clearer form?

I rather think the latter. Clive Thompson wrote last month in the NYT Magazine that constant digital updates, after a day, can begin “to feel like a short story; follow it for a month, and it’s a novel.” He was right to see the bits as part of a larger whole. The words now flying through our digital pipes & ether more or less tend to resemble parts of bigger units, perhaps even familiar genres. But stories and novels have definite conclusions; they also have conventional lengths. Quick, how long is the conventional blog, when you add up all of its posts and comments? How long is the longest email thread you send back and forth on a single topic?'''

word_count = dict()

for w in words.split(' '):
  if w in word_count:
    word_count[w] += 1
  else:
    word_count[w] = 1
print(word_count)
# Out:
# {'Lately,': 1, 'I’ve': 1, 'been': 1, 'noticing': 1, 'how': 3, 'my': 1, 'sentences': 1, 'have': 8, 'a': 12, 'tendency': 1, 'to': 12, 'keep': 1, 'going': 1, 'when': 2, 'I': 3, 'write': 2, 'them': 2, 'onscreen.': 1, 'This': 2, 'goes': 1, 'for': 3, 'concentrated': 1, 'writing': 2, 'as': 3, 'well': 1, 'correspondence.': 1, '(Twain': 1, 'probably': 1, 'believed': 1, 'that': 4, 'correspondence,': 1, 'in': 6, 'an': 2, 'ideal': 1, 'world,': 1, 'also': 3, 'demands': 1, 'concentration.': 1, 'But': 3, 'he': 1, 'never': 1, 'used': 1, 'email.)': 1, 'Last': 1, 'week': 1, 'caught': 1, 'myself': 1, 'packing': 1, 'four': 1, 'conjunctions': 2, 'into': 1, 'three-line': 1, 'sentence': 1, 'email.': 1, 'That’s': 1, 'inexcusable.': 1, 'Since': 1, 'then,': 1, 'tried': 1, 'eschew': 1, 'whenever': 1, 'possible.': 1, 'Gone': 1, 'are': 3, 'the': 13, 'commas,': 1, 'and’s,': 1, 'but’s,': 1, 'and': 9, 'so’s;': 1, 'staccato': 1, 'declaratives.': 1, 'Better': 1, 'read': 1, 'like': 2, 'bad': 2, 'Hemingway': 1, 'than': 1, 'Faulkner.\n\nLength–as': 1, 'we': 6, 'all': 3, 'know,': 1, 'lack': 1, 'of': 7, 'more': 2, 'original': 1, 'or': 3, 'effective': 1, 'way': 1, 'saying': 1, 'it–matters.': 1, '(ahem),': 1, 'it’s': 2, 'matter': 1, 'you': 3, 'use': 1, 'it.': 1, 'Style': 1, 'length': 1, 'technically': 1, 'two': 1, 'different': 1, 'things.\n\nTry': 1, 'putting': 1, 'some': 1, 'prose': 1, 'onscreen,': 1, 'though,': 1, 'they': 4, 'mix': 1, 'themselves': 1, 'up': 2, 'pretty': 1, 'quickly.': 1, 'has': 1, 'much': 1, 'do': 3, 'with': 2, 'time': 5, 'constraints': 1, 'claim': 1, 'feel': 2, 'digital': 3, 'age.': 1, 'We': 4, 'don’t': 4, 'compose': 1, 'letters': 1, 'post': 1, 'anymore–much': 1, 'less': 3, 'pay': 1, 'postage,': 1, 'what': 1, 'banks': 1, 'kinda-sorta': 1, 'losing': 1, 'our': 3, 'money': 1, 'these': 2, 'days–so': 1, 'blast': 1, 'few': 1, 'emails.': 2, 'talk,': 1, 'so': 3, 'text.': 1, 'text': 1, 'specific': 1, 'people,': 1, 'update': 1, 'Facebook': 1, 'status.': 1, 'essays,': 1, 'blog.\n\nI’m': 1, 'interested': 1, 'by': 1, 'superficial': 1, 'reduction': 1, 'words–i.e.': 1, 'always': 1, 'charming': 1, 'imho': 1, 'c': 1, 'u': 1, 'l8r–than': 1, 'genres': 1, 'which': 1, 'those': 1, 'communications': 1, 'occur:': 1, 'blogs,': 1, 'texts,': 1, 'tweets,': 1, 'All': 1, 'interstitial': 1, 'communiques,': 1, 'really': 1, 'reflect': 2, 'super': 1, 'brevity': 1, 'would': 1, 'make': 1, 'Twain': 1, 'proud?': 1, 'Or': 1, 'just': 1, 'poorly': 1, 'stylized': 1, 'desperately': 1, 'seeks': 1, 'clearer': 1, 'form?\n\nI': 1, 'rather': 1, 'think': 1, 'latter.': 1, 'Clive': 1, 'Thompson': 1, 'wrote': 1, 'last': 1, 'month': 1, 'NYT': 1, 'Magazine': 1, 'constant': 1, 'updates,': 1, 'after': 1, 'day,': 1, 'can': 1, 'begin': 1, '“to': 1, 'short': 1, 'story;': 1, 'follow': 1, 'it': 1, 'month,': 1, 'novel.”': 1, 'He': 1, 'was': 1, 'right': 1, 'see': 1, 'bits': 1, 'part': 1, 'larger': 1, 'whole.': 1, 'The': 1, 'words': 1, 'now': 1, 'flying': 1, 'through': 1, 'pipes': 1, '&': 1, 'ether': 1, 'tend': 1, 'resemble': 1, 'parts': 1, 'bigger': 1, 'units,': 1, 'perhaps': 1, 'even': 1, 'familiar': 1, 'genres.': 1, 'stories': 1, 'novels': 1, 'definite': 1, 'conclusions;': 1, 'conventional': 2, 'lengths.': 1, 'Quick,': 1, 'long': 2, 'is': 2, 'blog,': 1, 'add': 1, 'its': 1, 'posts': 1, 'comments?': 1, 'How': 1, 'longest': 1, 'email': 1, 'thread': 1, 'send': 1, 'back': 1, 'forth': 1, 'on': 1, 'single': 1, 'topic?': 1}

# %%
#Example 07:
dict_ = {'a':4,'b':1,'c':6,'d':2,'e':3}

new_dict = {k:v*5 for (k,v) in dict_.items()}
print(new_dict)
# Out:
# {'a': 20, 'b': 5, 'c': 30, 'd': 10, 'e': 15}

# %%
#Example 08:
dict_ = {'a':4,'b':1,'c':6,'d':2,'e':3}

new_dict = {k:v for (k,v) in dict_.items() if 'a' in k}
print(new_dict)
# Out:
# {'a': 4}

# %%
#Example 09:
dict_ = {'a':3,'b':12,'c':6,'d':10,'e':15,'f':9}

new_dict = {k:('even' if v % 2 == 0 else 'odd') for (k,v) in dict_.items()}
print(new_dict)
# Out:
# {'a': 'odd', 'b': 'even', 'c': 'even', 'd': 'even', 'e': 'odd', 'f': 'odd'}

# %%
#Example 10:
dict_ = {'a':20,'b':12,'c':6,'d':10,'e':15,'f':9}

new_dict = {k:v for (k,v) in dict_.items() if v% 2 == 0 if v%3==0}
print(new_dict)
# Out:
# {'b': 12, 'c': 6}

# %%
#Example 11:
mylist = ["apple", "banana", "cherry"]

dct = {k:len(k) for k in mylist}
print(dct)
# Out:
# {'apple': 5, 'banana': 6, 'cherry': 6}

# %%
#Example 12:

colors = dict()

colors={
    'black': '000000',
    'white': 'ffffff',
    'green': '008000'
}

for color,value in colors.items():
  color = color.upper()
  print(f'{color}:{value}')
# Out:
# BLACK:000000
# WHITE:ffffff
# GREEN:008000

# %%
#Example 13:
number = {
    'one' : 1,
    'two': 2,
    'three':3,
    'four': 4,
    'twelve': 12
}

new_number = {k:v for (k,v) in number.items() if v%2==0}
print(new_number)
multi = {k:v*2 for(k,v) in number.items()}
print(multi)
print(f'Min: {min(list(number.values()))}')
print(f'Max: {max(list(number.values()))}')
# Out:
# {'two': 2, 'four': 4, 'twelve': 12}
# {'one': 2, 'two': 4, 'three': 6, 'four': 8, 'twelve': 24}
# Min: 1
# Max: 12

# %%
#Example 14:
import builtins
students = {
    'Alice': {'math': 85,'science':92},
    'Bob': {'math':78,'science':89},
    'Charlie':{'math':95,'science':85}
}

def StdAvg(std):
  for value in std.values():
    sum_ = builtins.sum(list(value.values()))
    avg = sum_/len(value)
    print(avg)

StdAvg(students)
# Out:
# 88.5
# 83.5
# 90.0
