# %%
#Example 01:
str1 = 'Hello'
str2 = 'World!'
str3 = str1 + ' '+ str2
print(str3)
# Out:
# Hello World!

# %%
#Example 02:
str4 = '123'
num = int(str4) + 1
print(num)
# Out:
# 124

# %%
#Example 03:
fruit = 'banana'
letter = fruit[1]
print(letter)
x =3
w = fruit[x-1]
print(w)
# Out:
# a
# n

# %%
#Example 04:
fruit = 'banana'
i=0
while i < len(fruit):
  print(fruit[i])
  i+=1
# Out:
# b
# a
# n
# a
# n
# a

# %%
#Example 05:
sentence = 'Brown fox jump over the dog'

def findVowels(sentence):
  vowel = ''
  for char in sentence.lower():
     if char == 'a' or char == 'e' or char == 'i' or char =='u' or char == 'o':
      vowel += char
  print(vowel)

findVowels(sentence)
# Out:
# oouoeeo

# %%
#Example 06:
s = 'Monty Python'
print(s[:2])
print(s[1:5])
print(s[2:])
print(s[:])
print(s[2:7:2])
# Out:
# Mo
# onty
# nty Python
# Monty Python
# nyP

# %%
#Example 07:
num = input("Enter a number: ")

def findPalindrome(num):
  reverse = num[::-1]
  if num == reverse:
    print(num, "is Palindrome.")
  else:
    print(num, "is not Palindrome.")

findPalindrome(num)
# Out:
# Enter a number: 121
# 121 is Palindrome.

# %%
#Example 08:
word = 'banana'

if word == 'banana':
  print('Allright, bananas.')

if word < 'banana':
  print('Your word,' + word +',comes before banana.')
elif word > 'banana':
  print('Your word,'+ word + ', comes after banana.')
else:
  print('Allright, bananas.')
# Out:
# Allright, bananas.
# Allright, bananas.

# %%
#Example 09:
stuff = 'Hello World!'
print(stuff.capitalize())
print(stuff.center(20,'*'))
print(stuff.endswith('!'))
print(stuff.find('W'))
print(stuff.lstrip('He'))
print(stuff.replace('World','Rony'))
# Out:
# Hello world!
# ****Hello World!****
# True
# 6
# llo World!
# Hello Rony!

# %%
#Example 10:

def total(word):
  count = 0
  for char in word:
    count += 1
  return count

def upper(word):
  if(word == word.upper()):
    return "The Sentence is already in upper case."
  else:
    return word.upper()

sentence = input("Type a sentence: ")
print(total(sentence))
print(upper(sentence))
# Out:
# Type a sentence: I am Rony Hassan
# 16
# I AM RONY HASSAN

# %%
#Example 11:
A = [1,2,3,4,5]
print("".join(str(a) for a in A))
# Out:
# 12345

# %%
#Example 12:
def contain(word):
  if not word.startswith('a'):
    print("Error: name should starts with 'a'.")

name = input("Enter your name: ")
contain(name)
# Out:
# Enter your name: arik

# %%
#Example 13:
def contain(word):
  if not word.endswith('n'):
    print("Error: name should ends with 'n'.")

name = input("Enter your name: ")
contain(name)
# Out:
# Enter your name: rony
# Error: name should ends with 'n'.
