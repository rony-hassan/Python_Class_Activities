# %%
hours = int(input("Enter Hours: "))
rate = float(input("Enter Rate: "))

pay = hours * rate
print("Pay: ",pay)
# Out:
# Enter Hours: 35
# Enter Rate: 2.75
# Pay:  96.25

# %%
print (n = 7)
print (7 + 5)
print (5.2, "this", 4 - 2, "that", 5/2.0)
# Out:
# 5.2 this 2 that 2.5

# %%
var_1,var_2,var_3,var_4,var_5,var_6,var_7,var_8,var_9,var_10 = "All ","work ","and ","no ","play ","makes ","Jack ","a ","dull ","boy"
print(var_1 + var_2 + var_3 + var_4 + var_5 + var_6 + var_7 + var_8 + var_9 +var_10)
# Out:
# All work and no play makes Jack a dull boy

# %%
first_value = 6 * 1 - 2
print(first_value)

final_value = 6 * (1 - 2)
print(final_value)
# Out:
# 4
# -6

# %%
#Here the highest precedance goes to multiplicative sign. So the result is 6 * 1 = 6 and 6 - 2 = 4
first_value = 6 * 1 - 2
print(first_value)
"""
Here as we have used parenthesis so the value of 1 - 2 is -1 and then 6 * -1 = -6
"""
final_value = 6 * (1 - 2)
print(final_value)

# %%
bruce = 6
print(bruce + 4)
# Out:
# 10

# %%
noun1 = input("Enter a noun: ")

noun2 = input("Enter another noun: ")

plural_noun = input("Enter a plural noun: ")

verb_past = input("Enter a verb in past tense: ")

verb = input("Enter a verb: ")

adjective = input("Enter an adjective: ")

adverb = input("Enter an adverb: ")

story = f'''Once upon a time, there was a {adjective} {noun1} who loved to {verb} {adverb}. One day, it found a group of {plural_noun}
playing with a {noun2}. The {noun1} {verb_past} with joy and decided to join them. Together, they all {verb}ed happily ever after! '''

print(story)
# Out:
# Enter a noun: dog
# Enter another noun: ball
# Enter a plural noun: people
# Enter a verb in past tense: filled
# Enter a verb: play
# Enter an adjective: lonely
# Enter an adverb: football
# Once upon a time, there was a lonely dog who loved to play football. One day, it found a group of people
# playing with a ball. The dog filled with joy and decided to join them. Together, they all played happily ever after!
