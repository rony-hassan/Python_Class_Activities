# %%
print(123)
print("Hello World!")
# Out:
# 123
# Hello World!

# %%
x = 12.2
y = 14
print(x)
print(y)
print(x,y)
print("x: ",x, " y: ",y)
print("x: "+ str(x), "y: "+ str(y))
x = x + 10
print(x)
# Out:
# 12.2
# 14
# 12.2 14
# x:  12.2  y:  14
# x: 12.2 y: 14
# 22.2

# %%
print(type(12.3))
print(type("sdffd"))
print(type(12))
# Out:
# <class 'float'>
# <class 'str'>
# <class 'int'>
